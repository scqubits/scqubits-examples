# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

import scqubits as scq

# %%
scq.GUI()
# Out:
# ...
# Output(layout=Layout(width='975px'))

# %% [markdown]
# A reference to the (Figure, Axes) of the latest plot generated by the gui above is stored in a variable `GUI.fig_ax`, which can be easily accessed for further customization. For example:

# %%
fig, ax = scq.GUI.fig_ax
ax.set_xlabel(r"charge offset $n_g$")
fig
